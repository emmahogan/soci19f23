# %% [markdown]
# # **Lab 1**
# ---
# ### **Your Name:**
# ### **Group Members:**
# ### **Date:**
# ---
#
# **Instructions:** For each of the problems below, you may write your code either in the space provided or on a separate sheet of graph paper (clearly labeled with the problem number and your name on each sheet).

# %% [markdown]
# ## Section 1: Built-in Functions and Type Conversion Warm-up

# %% [markdown]
# ### Activity 1: Write a program that asks a user to input their year of birth, and prints a message telling them their approximate age. For example, if the user inputs "1966", the program should print "You are about 57 years old."

# %% [markdown]
# ## Section 2: Translating Code to Functions

# %% [markdown]
# ###Activity 2.1: Write a few lines of python code to right justify the word "Hello", printing the word with enough leading spaces so that the last letter is in column 70 of a computer display. *Hint: Use string concatenation and repetition.*

# %% [markdown]
# ###Activity 2.2: Now, write a function named "right_justify" that takes *any* input string, and **returns** the string right justified so that the last letter of the string is in column 70. After writing the function, call your function with a string of your choice. Use the following guidelines to write your function:
#
# **Function Name:** right_justify
#
# **Parameter(s):** str (string), the string to right justify
#
# **Return:** string, the right-justified version of the input string
#
# *Hint: Recall the built-in "len" function that returns the length of a string, so the value of len('Hello') would be 5*

# %% [markdown]
# ## Section 3: Stack Diagrams

# %%
def func1(num):
  new_num = num * num * num
  return new_name

def func2(str):
  str_length = len(str)
  triple = func1(str_length)
  return triple

func2("Wow")

# %% [markdown]
# ###Activity 3.1: List the **order of execution** for the program above (not counting blank lines).
#
#
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
# 7.
# 8.

# %% [markdown]
# ### (Optional) Activity 3.2: Draw a **stack diagram** for the program above.
